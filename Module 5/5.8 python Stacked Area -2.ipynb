# %% [markdown]
# # Stacked Area

# %%
import pandas as pd
df= pd.read_excel('Group performance.xlsx')

# %%
import matplotlib.pyplot as plt
plt.stackplot(df['month'],df['team1'], df['team2'], df['team3'], labels=['team1','team2','team3'])
plt.legend(loc='upper left')

# %%
df = pd.DataFrame({
    'sales': [4, 6, 3, 10, 9, 5],
    'signups': [5, 4, 7, 13, 15, 12],
    'visits': [21, 45, 26, 65, 79, 52],}, index=pd.date_range(start='2018/01/01', end='2018/07/01',freq='M'))
ax = df.plot.area()
