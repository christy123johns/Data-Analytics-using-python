# %% [markdown]
# ## Bar Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([5, 8, 3, 12])

plt.bar(x,y, color = "hotpink")
plt.title('Group members')
plt.show()

# %%
import pandas as pd
df= pd.read_excel('HR.xlsx')
df.head(2)
# Out:
#    employee_number  age              department  gender marital_status  \
# 0                1   41                   Sales  Female         Single
# 1                2   49  Research & Development    Male        Married
#
#   over_time  total_working_years  monthly_income  salary_2017  salary_2018  \
# 0       Yes                    8           59930       719160    798260.76
# 1        No                   10           51300       615600    757180.80
#
#    year_of_joining
# 0             2012
# 1             2008

# %%
df['department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: department, dtype: int64

# %%
df['department'].value_counts().plot(kind='bar', color='b')
# Out:
# <AxesSubplot:>

# %%
ms=df['marital_status'].value_counts()
ms
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: marital_status, dtype: int64

# %%
ms.plot(kind="barh", color="lightblue",width = 0.6, edgecolor = 'black')
plt.title('Marital Status\n', fontdict={'fontsize':18, 'fontweight':5, 'color':'darkblue'})
# Out:
# Text(0.5, 1.0, 'Marital Status\n')
