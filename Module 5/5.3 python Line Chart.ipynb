# %% [markdown]
# # Line Chart

# %%
import pandas as pd
dict_line = {
    'year': [2016, 2017, 2018, 2019, 2020, 2021],
    'price': [200, 250, 260, 220, 280, 300]}
df_line = pd.DataFrame(dict_line)

# %%
# use plot() method on the dataframe
df_line.plot('year', 'price')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df= pd.read_excel('Group performance.xlsx')
df.head(15)
# Out:
#     month  team1  team2  team3
# 0       1     25     21     13
# 1       2     20     22     22
# 2       3     18     21     20
# 3       4     23     24     22
# 4       5     19     24     14
# 5       6     21     20     13
# 6       7     16     20     17
# 7       8     23     23     17
# 8       9     17     22     13
# 9      10     22     21     14
# 10     11     22     21     22
# 11     12     21     20     25

# %%
import matplotlib.pyplot as plt
 
# use the plot function
plt.plot(df['month'],df['team1'])

# %%
plt.plot(df['month'],df['team2'], color='b',marker='X')
