# %% [markdown]
# ## Area Chart

# %%
import pandas as pd
df= pd.read_excel('Group performance.xlsx')
df.head(2)
# Out:
#    month  team1  team2  team3
# 0      1     25     21     13
# 1      2     20     22     22

# %%
import matplotlib.pyplot as plt
plt.fill_between(df['month'],df['team1'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.fill_between(df['month'],df['team2'])
plt.show()
