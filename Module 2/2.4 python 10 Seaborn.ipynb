# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
data1=sns.load_dataset('iris')
data1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read excel file 

df = pd.read_excel('Online_Store_customer_data.xlsx')
df.head(3)
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status State_names  \
# 0       2019-01-01          151200  Female   19         Single      Kansas
# 1       2019-01-01          151201    Male   49         Single    Illinois
# 2       2019-01-01          151202    Male   63        Married  New Mexico
#
#   Segment Employees_status Payment_method  Amount_spent
# 0   Basic     Unemployment          Other       2051.36
# 1   Basic    self-employed           Card        544.04
# 2   Basic          workers         PayPal       1572.60

# %%
sns.barplot(df['Payment_method'],df['Amount_spent'])
plt.show()
# Out:
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(df['Payment_method'],df['Amount_spent'], color='yellow')
plt.show()
# Out:
# C:\Users\kchri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x= 'Payment_method',data= df, palette='Blues')
# Out:
# <AxesSubplot:xlabel='Payment_method', ylabel='count'>

# %%
sns.countplot(x= 'Payment_method',hue= 'Gender',data= df, palette='rocket')
# Out:
# <AxesSubplot:xlabel='Payment_method', ylabel='count'>

# %%
sns.boxplot(x='Payment_method',y='Amount_spent', data=df)
# Out:
# <AxesSubplot:xlabel='Payment_method', ylabel='Amount_spent'>
