# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('Online_Store_customer_data - Row.xlsx')

# %%
df.head(15)
# Out:
#    Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0        2019-01-01        151200.0  Female  19.0         Single       Kansas
# 1        2019-01-01        151201.0    Male  49.0         Single     Illinois
# 2        2019-01-01        151202.0    Male  63.0        Married   New Mexico
# 3        2019-01-01        151203.0  Female  18.0         Single     Virginia
# 4        2019-01-01        151204.0    Male  27.0         Single  Connecticut
# 5        2019-03-01        151205.0    Male  71.0         Single       Hawaii
# 6        2019-03-01        151206.0  Female  34.0        Married   New Mexico
# 7        2019-03-01        151207.0    Male  37.0        Married  Connecticut
# 8        2019-04-01        151208.0    Male  75.0        Married      Florida
# 9        2019-04-01        151209.0  Female  41.0        Married      Vermont
# 10              NaT             NaN     NaN   NaN            NaN          NaN
# ...

# %%
df.shape
# Out:
# (162, 10)

# %%
df.isnull().sum()
# Out:
# Transaction_date    12
# Transaction_ID      12
# Gender              12
# Age                 12
# Marital_status      12
# State_names         12
# Segment             12
# Employees_status    12
# Payment_method      12
# Amount_spent        12
# dtype: int64

# %%
df.drop([10,11],axis=0,inplace=True)
df.head(15)
# Out:
#    Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0        2019-01-01        151200.0  Female  19.0         Single
# 1        2019-01-01        151201.0    Male  49.0         Single
# 2        2019-01-01        151202.0    Male  63.0        Married
# 3        2019-01-01        151203.0  Female  18.0         Single
# 4        2019-01-01        151204.0    Male  27.0         Single
# 5        2019-03-01        151205.0    Male  71.0         Single
# 6        2019-03-01        151206.0  Female  34.0        Married
# 7        2019-03-01        151207.0    Male  37.0        Married
# 8        2019-04-01        151208.0    Male  75.0        Married
# 9        2019-04-01        151209.0  Female  41.0        Married
# 12       2019-04-01        151210.0  Female  56.0        Married
# 13       2019-05-01        151211.0  Female  63.0        Married
# 14       2019-05-01        151212.0  Female  60.0        Married
# ...

# %%
df.shape
# Out:
# (160, 10)

# %%
#all NaN values are not removed

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#     Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0         2019-01-01        151200.0  Female  19.0         Single
# 1         2019-01-01        151201.0    Male  49.0         Single
# 2         2019-01-01        151202.0    Male  63.0        Married
# 3         2019-01-01        151203.0  Female  18.0         Single
# 4         2019-01-01        151204.0    Male  27.0         Single
# ..               ...             ...     ...   ...            ...
# 157       2019-11-05        151581.0  Female  65.0        Married
# 158       2019-12-05        151582.0  Female  24.0        Married
# 159       2019-12-05        151583.0    Male  66.0         Single
# 160       2019-12-05        151584.0  Female  26.0        Married
# 161       2019-12-05        151585.0    Male  68.0        Married
#
#       State_names   Segment Employees_status Payment_method  Amount_spent
# 0          Kansas     Basic     Unemployment          Other       2051.36
# ...

# %%
df.shape
# Out:
# (150, 10)
