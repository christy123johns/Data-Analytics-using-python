# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('Online_Store_customer_data.xlsx')

# %%
df
# Out:
#     Transaction_date  Transaction_ID  Gender  Age Marital_status  \
# 0         2019-01-01          151200  Female   19         Single
# 1         2019-01-01          151201    Male   49         Single
# 2         2019-01-01          151202    Male   63        Married
# 3         2019-01-01          151203  Female   18         Single
# 4         2019-01-01          151204    Male   27         Single
# ..               ...             ...     ...  ...            ...
# 145       2019-11-05          151581  Female   65        Married
# 146       2019-12-05          151582  Female   24        Married
# 147       2019-12-05          151583    Male   66         Single
# 148       2019-12-05          151584  Female   26        Married
# 149       2019-12-05          151585    Male   68        Married
#
#       State_names   Segment Employees_status Payment_method  Amount_spent
# 0          Kansas     Basic     Unemployment          Other       2051.36
# ...

# %%
df.isnull().sum()
# Out:
# Transaction_date    0
# Transaction_ID      0
# Gender              0
# Age                 0
# Marital_status      0
# State_names         0
# Segment             0
# Employees_status    0
# Payment_method      0
# Amount_spent        0
# dtype: int64

# %%
# create new df_col dataframe from df.copy() method. 
df_col = df.copy()

# %%
df_col.loc[df_col.Gender == "Female", 'Gender'] = 'F' 
df_col.loc[df_col.Gender == "Male", 'Gender'] = 'M'

# %%
df_col.head(10)
# Out:
#   Transaction_date  Transaction_ID Gender  Age Marital_status  State_names  \
# 0       2019-01-01          151200      F   19         Single       Kansas
# 1       2019-01-01          151201      M   49         Single     Illinois
# 2       2019-01-01          151202      M   63        Married   New Mexico
# 3       2019-01-01          151203      F   18         Single     Virginia
# 4       2019-01-01          151204      M   27         Single  Connecticut
# 5       2019-03-01          151205      M   71         Single       Hawaii
# 6       2019-03-01          151206      F   34        Married   New Mexico
# 7       2019-03-01          151207      M   37        Married  Connecticut
# 8       2019-04-01          151208      M   75        Married      Florida
# 9       2019-04-01          151209      F   41        Married      Vermont
#
#     Segment Employees_status Payment_method  Amount_spent
# 0     Basic     Unemployment          Other       2051.36
# ...

# %%
# rename columns name
df_col.rename(columns={"Transaction_date": "Date", "Gender": "Sex"}, inplace=True)
df_col.head(3)
# Out:
#         Date  Transaction_ID Sex  Age Marital_status State_names Segment  \
# 0 2019-01-01          151200   F   19         Single      Kansas   Basic
# 1 2019-01-01          151201   M   49         Single    Illinois   Basic
# 2 2019-01-01          151202   M   63        Married  New Mexico   Basic
#
#   Employees_status Payment_method  Amount_spent
# 0     Unemployment          Other       2051.36
# 1    self-employed           Card        544.04
# 2          workers         PayPal       1572.60

# %%
df_col.head(2)
# Out:
#         Date  Transaction_ID Sex  Age Marital_status State_names Segment  \
# 0 2019-01-01          151200   F   19         Single      Kansas   Basic
# 1 2019-01-01          151201   M   49         Single    Illinois   Basic
#
#   Employees_status Payment_method  Amount_spent
# 0     Unemployment          Other       2051.36
# 1    self-employed           Card        544.04

# %%
df.head(2)
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status State_names  \
# 0       2019-01-01          151200  Female   19         Single      Kansas
# 1       2019-01-01          151201    Male   49         Single    Illinois
#
#   Segment Employees_status Payment_method  Amount_spent
# 0   Basic     Unemployment          Other       2051.36
# 1   Basic    self-employed           Card        544.04
