# %% [markdown]
# # #Import libraries

# %%
import numpy as np
import pandas as pd

# %%
# read csv file

df = pd.read_excel('Online_Store_customer_data.xlsx')
df.head(4)
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status State_names  \
# 0       2019-01-01          151200  Female   19         Single      Kansas
# 1       2019-01-01          151201    Male   49         Single    Illinois
# 2       2019-01-01          151202    Male   63        Married  New Mexico
# 3       2019-01-01          151203  Female   18         Single    Virginia
#
#     Segment Employees_status Payment_method  Amount_spent
# 0     Basic     Unemployment          Other       2051.36
# 1     Basic    self-employed           Card        544.04
# 2     Basic          workers         PayPal       1572.60
# 3  Platinum          workers           Card       1199.79

# %% [markdown]
# ### Data Exploring

# %%
# display first 5 rows
df.head(3)
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status State_names  \
# 0       2019-01-01          151200  Female   19         Single      Kansas
# 1       2019-01-01          151201    Male   49         Single    Illinois
# 2       2019-01-01          151202    Male   63        Married  New Mexico
#
#   Segment Employees_status Payment_method  Amount_spent
# 0   Basic     Unemployment          Other       2051.36
# 1   Basic    self-employed           Card        544.04
# 2   Basic          workers         PayPal       1572.60

# %%
# display last 4 rows
df.tail(6)
# Out:
#     Transaction_date  Transaction_ID  Gender  Age Marital_status  \
# 144       2019-11-05          151580    Male   56        Married
# 145       2019-11-05          151581  Female   65        Married
# 146       2019-12-05          151582  Female   24        Married
# 147       2019-12-05          151583    Male   66         Single
# 148       2019-12-05          151584  Female   26        Married
# 149       2019-12-05          151585    Male   68        Married
#
#       State_names Segment Employees_status Payment_method  Amount_spent
# 144        Oregon    Gold          workers         PayPal        288.93
# 145         Maine   Basic    self-employed         PayPal       2564.80
# 146    New Jersey   Basic          workers           Card        147.79
# 147       Montana   Basic          workers          Other        488.21
# 148  Pennsylvania   Basic     Unemployment           Card        376.84
# 149     Louisiana  Silver    self-employed          Other       2437.16

# %%
# for display uniqe values of State_names column
df['State_names'].unique()
# Out:
# array(['Kansas', 'Illinois', 'New Mexico', 'Virginia', 'Connecticut',
#        'Hawaii', 'Florida', 'Vermont', 'California', 'Colorado', 'Iowa',
#        'South Carolina', 'New York', 'Maine', 'Maryland', 'Missouri',
#        'North Dakota', 'Ohio', 'Nebraska', 'Montana', 'Indiana',
#        'Wisconsin', 'Alabama', 'Oklahoma', 'Oregon', 'Nevada',
#        'New Jersey', 'Louisiana', 'Massachusetts', 'Rhode Island',
#        'Arkansas', 'Michigan', 'Utah', 'Arizona', 'New Hampshire',
#        'Wyoming', 'Tennessee', 'Georgia', 'Mississippi', 'Idaho',
#        'North Carolina', 'West Virginia', 'Alaska', 'Minnesota', 'Texas',
#        'South Dakota', 'Pennsylvania'], dtype=object)

# %%
# Display random 6 sample rows
#random sample generting
df.sample(6)
# Out:
#     Transaction_date  Transaction_ID  Gender  Age Marital_status State_names  \
# 111       2019-10-04          151476  Female   74        Married     Florida
# 116       2019-11-04          151481  Female   46        Married    Oklahoma
# 3         2019-01-01          151203  Female   18         Single    Virginia
# 120       2019-12-04          151485  Female   55        Married     Arizona
# 144       2019-11-05          151580    Male   56        Married      Oregon
# 129       2019-06-05          151561    Male   54        Married     Alabama
#
#       Segment Employees_status Payment_method  Amount_spent
# 111     Basic          workers          Other       2076.39
# 116     Basic        Employees           Card       1757.27
# 3    Platinum          workers           Card       1199.79
# 120     Basic    self-employed          Other       2773.68
# 144      Gold          workers         PayPal        288.93
# 129     Basic     Unemployment         PayPal       1264.38

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  150 non-null    datetime64[ns]
#  1   Transaction_ID    150 non-null    int64
#  2   Gender            150 non-null    object
#  3   Age               150 non-null    int64
#  4   Marital_status    150 non-null    object
#  5   State_names       150 non-null    object
#  6   Segment           150 non-null    object
#  7   Employees_status  150 non-null    object
#  8   Payment_method    150 non-null    object
#  9   Amount_spent      150 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 11.8+ KB

# %%
# display datatypes
df.dtypes
# Out:
# Transaction_date    datetime64[ns]
# Transaction_ID               int64
# Gender                      object
# Age                          int64
# Marital_status              object
# State_names                 object
# Segment                     object
# Employees_status            object
# Payment_method              object
# Amount_spent               float64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object            6
# int64             2
# datetime64[ns]    1
# float64           1
# dtype: int64

# %%
df.shape
# Out:
# (150, 10)

# %%
df.columns
# Out:
# Index(['Transaction_date', 'Transaction_ID', 'Gender', 'Age', 'Marital_status',
#        'State_names', 'Segment', 'Employees_status', 'Payment_method',
#        'Amount_spent'],
#       dtype='object')

# %% [markdown]
# # Slicing of data

# %%
# display Age columns first 3 rows data
df['Age'].head(3)
# Out:
# 0    19
# 1    49
# 2    63
# Name: Age, dtype: int64

# %%
# display first 4 rows of Age, Transaction_date and Gender columns
df[['Age', 'Transaction_date', 'Gender']].head(4)
# Out:
#    Age Transaction_date  Gender
# 0   19       2019-01-01  Female
# 1   49       2019-01-01    Male
# 2   63       2019-01-01    Male
# 3   18       2019-01-01  Female

# %%
# for display 2nd to 7th rows
df[2:7]
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status  State_names  \
# 2       2019-01-01          151202    Male   63        Married   New Mexico
# 3       2019-01-01          151203  Female   18         Single     Virginia
# 4       2019-01-01          151204    Male   27         Single  Connecticut
# 5       2019-03-01          151205    Male   71         Single       Hawaii
# 6       2019-03-01          151206  Female   34        Married   New Mexico
#
#     Segment Employees_status Payment_method  Amount_spent
# 2     Basic          workers         PayPal       1572.60
# 3  Platinum          workers           Card       1199.79
# 4     Basic    self-employed           Card       2530.60
# 5     Basic        Employees         PayPal       2922.66
# 6  Platinum        Employees         PayPal       1481.42

# %%
# for display 
df[:15]
# Out:
#    Transaction_date  Transaction_ID  Gender  Age Marital_status  \
# 0        2019-01-01          151200  Female   19         Single
# 1        2019-01-01          151201    Male   49         Single
# 2        2019-01-01          151202    Male   63        Married
# 3        2019-01-01          151203  Female   18         Single
# 4        2019-01-01          151204    Male   27         Single
# 5        2019-03-01          151205    Male   71         Single
# 6        2019-03-01          151206  Female   34        Married
# 7        2019-03-01          151207    Male   37        Married
# 8        2019-04-01          151208    Male   75        Married
# 9        2019-04-01          151209  Female   41        Married
# 10       2019-04-01          151210  Female   56        Married
# 11       2019-05-01          151211  Female   63        Married
# 12       2019-05-01          151212  Female   60        Married
# 13       2019-05-01          151213    Male   47         Single
# ...

# %%
# for display last two rows
df[-2:]
# Out:
#     Transaction_date  Transaction_ID  Gender  Age Marital_status  \
# 148       2019-12-05          151584  Female   26        Married
# 149       2019-12-05          151585    Male   68        Married
#
#       State_names Segment Employees_status Payment_method  Amount_spent
# 148  Pennsylvania   Basic     Unemployment           Card        376.84
# 149     Louisiana  Silver    self-employed          Other       2437.16

# %%
df[-10:]
# Out:
#     Transaction_date  Transaction_ID  Gender  Age Marital_status  \
# 140       2019-10-05          151576  Female   51         Single
# 141       2019-10-05          151577    Male   26         Single
# 142       2019-10-05          151578    Male   28        Married
# 143       2019-11-05          151579    Male   67        Married
# 144       2019-11-05          151580    Male   56        Married
# 145       2019-11-05          151581  Female   65        Married
# 146       2019-12-05          151582  Female   24        Married
# 147       2019-12-05          151583    Male   66         Single
# 148       2019-12-05          151584  Female   26        Married
# 149       2019-12-05          151585    Male   68        Married
#
#       State_names   Segment Employees_status Payment_method  Amount_spent
# 140      Oklahoma    Silver    self-employed           Card        979.14
# 141      Missouri    Silver        Employees         PayPal       1521.48
# ...

# %%
# Access to the column transaction date
x=df[['Transaction_date']]
x.head(2)
# Out:
#   Transaction_date
# 0       2019-01-01
# 1       2019-01-01

# %%
#To access column transaction date in a series format
y=df['Transaction_date'] 
y.head(3)
# Out:
# 0   2019-01-01
# 1   2019-01-01
# 2   2019-01-01
# Name: Transaction_date, dtype: datetime64[ns]

# %%
# Access to multiple columns
y=df[['Gender','Age','Marital_status']]
y
# Out:
#      Gender  Age Marital_status
# 0    Female   19         Single
# 1      Male   49         Single
# 2      Male   63        Married
# 3    Female   18         Single
# 4      Male   27         Single
# ..      ...  ...            ...
# 145  Female   65        Married
# 146  Female   24        Married
# 147    Male   66         Single
# 148  Female   26        Married
# 149    Male   68        Married
#
# [150 rows x 3 columns]

# %%
# Access the value on the first row and the first column
df.iloc[0,0]
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
df.iloc[1,0]
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
df.iloc[4,2]
# Out:
# 'Male'

# %%
# Access the column using the variable name
df.loc[5,'Marital_status']
# Out:
# 'Single'

# %%
df.loc[71,'Segment']
# Out:
# 'Basic'

# %%
df.loc[1:17,'Age']
# Out:
# 1     49
# 2     63
# 3     18
# 4     27
# 5     71
# 6     34
# 7     37
# 8     75
# 9     41
# 10    56
# 11    63
# 12    60
# 13    47
# 14    24
# 15    16
# 16    72
# 17    77
# Name: Age, dtype: int64

# %%
# slicing the dataframe
df.iloc[0:6,2:4]
# Out:
#    Gender  Age
# 0  Female   19
# 1    Male   49
# 2    Male   63
# 3  Female   18
# 4    Male   27
# 5    Male   71

# %%
df.iloc[1:40,0:4]
# Out:
#    Transaction_date  Transaction_ID  Gender  Age
# 1        2019-01-01          151201    Male   49
# 2        2019-01-01          151202    Male   63
# 3        2019-01-01          151203  Female   18
# 4        2019-01-01          151204    Male   27
# 5        2019-03-01          151205    Male   71
# 6        2019-03-01          151206  Female   34
# 7        2019-03-01          151207    Male   37
# 8        2019-04-01          151208    Male   75
# 9        2019-04-01          151209  Female   41
# 10       2019-04-01          151210  Female   56
# 11       2019-05-01          151211  Female   63
# 12       2019-05-01          151212  Female   60
# 13       2019-05-01          151213    Male   47
# 14       2019-05-01          151214    Male   24
# 15       2019-06-01          151215    Male   16
# 16       2019-06-01          151216  Female   72
# 17       2019-07-01          151217  Female   77
# 18       2019-07-01          151218    Male   42
# ...

# %% [markdown]
# # Slice the data according to age >25

# %%
# Age more than 25

Slice_Age = df['Age'] > 25
Slice_Age.head()
df_Age = df.loc[Slice_Age] 
df_Age.head()
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status  State_names  \
# 1       2019-01-01          151201    Male   49         Single     Illinois
# 2       2019-01-01          151202    Male   63        Married   New Mexico
# 4       2019-01-01          151204    Male   27         Single  Connecticut
# 5       2019-03-01          151205    Male   71         Single       Hawaii
# 6       2019-03-01          151206  Female   34        Married   New Mexico
#
#     Segment Employees_status Payment_method  Amount_spent
# 1     Basic    self-employed           Card        544.04
# 2     Basic          workers         PayPal       1572.60
# 4     Basic    self-employed           Card       2530.60
# 5     Basic        Employees         PayPal       2922.66
# 6  Platinum        Employees         PayPal       1481.42

# %%
df
# Out:
#     Transaction_date  Transaction_ID  Gender  Age Marital_status  \
# 0         2019-01-01          151200  Female   19         Single
# 1         2019-01-01          151201    Male   49         Single
# 2         2019-01-01          151202    Male   63        Married
# 3         2019-01-01          151203  Female   18         Single
# 4         2019-01-01          151204    Male   27         Single
# ..               ...             ...     ...  ...            ...
# 145       2019-11-05          151581  Female   65        Married
# 146       2019-12-05          151582  Female   24        Married
# 147       2019-12-05          151583    Male   66         Single
# 148       2019-12-05          151584  Female   26        Married
# 149       2019-12-05          151585    Male   68        Married
#
#       State_names   Segment Employees_status Payment_method  Amount_spent
# 0          Kansas     Basic     Unemployment          Other       2051.36
# ...

# %%
Slice_Age.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# Name: Age, dtype: bool

# %%
print(len(df_Age))
# Out:
# 125

# %%
df_Age.shape
# Out:
# (125, 10)

# %%
Slice_Age = df['Age'] > 25
Slice_Age_1 = df['Age'] <50
Slice_Age.head()
df_Age = df.loc[Slice_Age & Slice_Age_1] 
df_Age.head()
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status  State_names  \
# 1       2019-01-01          151201    Male   49         Single     Illinois
# 4       2019-01-01          151204    Male   27         Single  Connecticut
# 6       2019-03-01          151206  Female   34        Married   New Mexico
# 7       2019-03-01          151207    Male   37        Married  Connecticut
# 9       2019-04-01          151209  Female   41        Married      Vermont
#
#     Segment Employees_status Payment_method  Amount_spent
# 1     Basic    self-employed           Card        544.04
# 4     Basic    self-employed           Card       2530.60
# 6  Platinum        Employees         PayPal       1481.42
# 7     Basic          workers         PayPal       1149.55
# 9      Gold     Unemployment           Card       2730.60

# %%
Slice_Age.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# Name: Age, dtype: bool

# %%
print(len(df_Age))
# Out:
# 60

# %%
df_Age.shape
# Out:
# (60, 10)
