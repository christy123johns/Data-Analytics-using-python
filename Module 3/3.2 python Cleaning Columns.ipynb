# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Removing columns

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('Online_Store_customer_data - Col.xlsx')

# %%
df
# Out:
#     Transaction_date  Transaction_ID  Address  Gender  Age Marital_status  \
# 0         2019-01-01          151200      NaN  Female   19         Single
# 1         2019-01-01          151201      NaN    Male   49         Single
# 2         2019-01-01          151202      NaN    Male   63        Married
# 3         2019-01-01          151203      NaN  Female   18         Single
# 4         2019-01-01          151204      NaN    Male   27         Single
# ..               ...             ...      ...     ...  ...            ...
# 145       2019-11-05          151581      NaN  Female   65        Married
# 146       2019-12-05          151582      NaN  Female   24        Married
# 147       2019-12-05          151583      NaN    Male   66         Single
# 148       2019-12-05          151584      NaN  Female   26        Married
# 149       2019-12-05          151585      NaN    Male   68        Married
#
#      Country   State_names   Segment Employees_status Payment_method  \
# ...

# %%
df.head()
# Out:
#   Transaction_date  Transaction_ID  Address  Gender  Age Marital_status  \
# 0       2019-01-01          151200      NaN  Female   19         Single
# 1       2019-01-01          151201      NaN    Male   49         Single
# 2       2019-01-01          151202      NaN    Male   63        Married
# 3       2019-01-01          151203      NaN  Female   18         Single
# 4       2019-01-01          151204      NaN    Male   27         Single
#
#    Country  State_names   Segment Employees_status Payment_method  \
# 0      NaN       Kansas     Basic     Unemployment          Other
# 1      NaN     Illinois     Basic    self-employed           Card
# 2      NaN   New Mexico     Basic          workers         PayPal
# 3      NaN     Virginia  Platinum          workers           Card
# 4      NaN  Connecticut     Basic    self-employed           Card
#
#    Amount_spent
# 0       2051.36
# 1        544.04
# 2       1572.60
# 3       1199.79
# 4       2530.60

# %%
df.shape
# Out:
# (150, 12)

# %%
df.columns
# Out:
# Index(['Transaction_date', 'Transaction_ID', 'Address', 'Gender', 'Age',
#        'Marital_status', 'Country', 'State_names', 'Segment',
#        'Employees_status', 'Payment_method', 'Amount_spent'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Address             150
# Gender                0
# Age                   0
# Marital_status        0
# Country             150
# State_names           0
# Segment               0
# Employees_status      0
# Payment_method        0
# Amount_spent          0
# dtype: int64

# %%
#axis =1 indicates columns
df.drop(['Address','Country'],axis=1,inplace=True)

# %%
df
# Out:
#     Transaction_date  Transaction_ID  Gender  Age Marital_status  \
# 0         2019-01-01          151200  Female   19         Single
# 1         2019-01-01          151201    Male   49         Single
# 2         2019-01-01          151202    Male   63        Married
# 3         2019-01-01          151203  Female   18         Single
# 4         2019-01-01          151204    Male   27         Single
# ..               ...             ...     ...  ...            ...
# 145       2019-11-05          151581  Female   65        Married
# 146       2019-12-05          151582  Female   24        Married
# 147       2019-12-05          151583    Male   66         Single
# 148       2019-12-05          151584  Female   26        Married
# 149       2019-12-05          151585    Male   68        Married
#
#       State_names   Segment Employees_status Payment_method  Amount_spent
# 0          Kansas     Basic     Unemployment          Other       2051.36
# ...
